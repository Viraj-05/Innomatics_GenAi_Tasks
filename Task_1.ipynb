# %% [markdown]
# # Assignment: Mastering Prompt Templates in LangChain

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
template_1 = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms for beginners"
)
def explain_topic(topic):
    return template_1.format(topic=topic)

print(explain_topic("Artificial Intelligence"))
# Out:
# Explain Artificial Intelligence in simple terms for beginners

# %% [markdown]
# Multi-Input Prompt System

# %%
multi_template = PromptTemplate(
    input_variables=["topic", "audience", "tone"],
    template="Explain {topic} for {audience} in a {tone} tone"
)

# Test cases
print(multi_template.format(topic="AI", audience="beginners", tone="friendly"))
print(multi_template.format(topic="Python", audience="kids", tone="fun"))
print(multi_template.format(topic="Deep Learning", audience="engineers", tone="technical"))
# Out:
# Explain AI for beginners in a friendly tone
# Explain Python for kids in a fun tone
# Explain Deep Learning for engineers in a technical tone

# %% [markdown]
# Prompt Variations Engine

# %%
teaching_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} clearly step by step"
)

interview_template = PromptTemplate(
    input_variables=["topic"],
    template="Ask 3 interview questions about {topic}"
)

story_template = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} as a story"
)

topic = "Machine Learning"

print(teaching_template.format(topic=topic))
print(interview_template.format(topic=topic))
print(story_template.format(topic=topic))
# Out:
# Explain Machine Learning clearly step by step
# Ask 3 interview questions about Machine Learning
# Explain Machine Learning as a story

# %% [markdown]
# ChatPromptTemplate System

# %%
def chat_prompt(role, topic):
    
    role_map = {
        "teacher": "You are a helpful teacher who explains concepts clearly.",
        "interviewer": "You are an interviewer who asks deep questions.",
        "motivator": "You are a motivational speaker who inspires learning."
    }
    
    chat_template = ChatPromptTemplate.from_messages([
        ("system", role_map.get(role, "You are a helpful assistant.")),
        ("user", "Explain {topic}")
    ])
    
    return chat_template.format_messages(topic=topic)

# Testing 
messages = chat_prompt("teacher", "Neural Networks")

for msg in messages:
    print(msg)
# Out:
# content='You are a helpful teacher who explains concepts clearly.' additional_kwargs={} response_metadata={}
# content='Explain Neural Networks' additional_kwargs={} response_metadata={}

# %% [markdown]
# Input Validation Layer

# %%
def validate_inputs(audience, tone):
    
    valid_audience = ["beginner", "intermediate", "expert"]
    valid_tone = ["formal", "casual", "fun"]
    
    if audience not in valid_audience:
        audience = "beginner"
    
    if tone not in valid_tone:
        tone = "formal"
    
    return audience, tone

# Test
print(validate_inputs("kids", "funny"))
# Out:
# ('beginner', 'formal')

# %% [markdown]
# Prompt Generator App

# %%
style_map = {
    "teaching": "Explain {topic} for {audience} in a {tone} teaching style",
    "interview": "Generate interview questions about {topic} for {audience} in a {tone} tone",
    "storytelling": "Explain {topic} for {audience} in a {tone} storytelling style"
}

def generate_prompt(topic, audience, tone, style):
    
    audience, tone = validate_inputs(audience, tone)
    
    if style not in style_map:
        style = "teaching"
    
    template = PromptTemplate(
        input_variables=["topic", "audience", "tone"],
        template=style_map[style]
    )
    
    return template.format(topic=topic, audience=audience, tone=tone)

# Test
print(generate_prompt("Neural Networks", "beginner", "fun", "storytelling"))
# Out:
# Explain Neural Networks for beginner in a fun storytelling style

# %% [markdown]
# Template Reusability Test

# %%
reusable_template = PromptTemplate(
    input_variables=["topic"],
    template="Provide a simple explanation of {topic}"
)

topics = ["AI", "Blockchain", "Cloud Computing", "Cyber Security", "Data Science"]

for t in topics:
    print(reusable_template.format(topic=t))
# Out:
# Provide a simple explanation of AI
# Provide a simple explanation of Blockchain
# Provide a simple explanation of Cloud Computing
# Provide a simple explanation of Cyber Security
# Provide a simple explanation of Data Science

# %% [markdown]
# Final Pipeline Flow

# %%
def full_pipeline(topic, audience, tone, style):
    
    audience, tone = validate_inputs(audience, tone)
    
    prompt = generate_prompt(topic, audience, tone, style)
    
    return prompt

# Testing

print(full_pipeline("Machine Learning", "beginner", "fun", "teaching"))
# Out:
# Explain Machine Learning for beginner in a fun teaching style
